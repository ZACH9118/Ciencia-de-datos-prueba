# %%
venderdores =["ana","briayan","camila"]
print(venderdores)
# Out:
# ['ana', 'briayan', 'camila']

# %%
1+5
# Out:
# 6

# %%
vendedores = [
    {"nome": "Ana", "vendas": 1500},
    {"nome": "Bruno", "vendas": 2300},
    {"nome": "Carla", "vendas": 1800},
    {"nome": "Daniel", "vendas": 1200},
    {"nome": "Eva", "vendas": 2000}]
total_vendas = sum(vendedor["vendas"] for vendedor in vendedores)
print(f"Total de vendas: R$ {total_vendas:.2f}")
# Out:
# Total de vendas: R$ 8800.00
